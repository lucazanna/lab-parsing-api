# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
url = "https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=popularity"

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
import json
import requests
import pandas as pd

response = requests.get(url, headers ={"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"})

results = response.json()
results


flattened_data = pd.json_normalize(results)

flattened_data1 = pd.json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
#               sku                                               name  \
# 0   TO122O0AA-C11                             T-shirt imprimé - grey
# 1   IJ022E012-M11                 ALEX - Pantalon cargo - dark green
# 2   TI112K02P-O11     NEWMARKET LOW BOOT - Bottines à lacets - wheat
# 3   NE212O04O-K11                          Baskets basses - grey/red
# 4   N1242A1RJ-M11  COURT AIR ZOOM - Chaussures de tennis toutes s...
# ..            ...                                                ...
# 79  TH342D00W-H11  MEN’S REDBOX TEE - T-shirt imprimé - flame orange
# 80  KIE22O00T-G11              T-shirt imprimé - burgundy/white/navy
# 81  TO222E04K-B11             WASHED STRUCTURE CHINO - Chino - beige
# 82  PU142E0N3-C11                              Short - asphalt-black
# 83  L0642D04I-K13  TENNIS BLOCK - T-shirt imprimé - navy blue/tur...
#
#                                                 sizes  \
# 0                                           [S, M, L]
# ...

# %%
total_pages=results['pagination']['page_count']
print(total_pages)
# Out:
# 892

# %%
# Your code
df=pd.DataFrame()
for i in range(5):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset={k}&sort=sale'
    response = requests.get(url, headers ={"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"})
    results = response.json()
    flattened_data = pd.json_normalize(results)
    flattened_data1 = pd.json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df.head(5)
# Out:
#                                                             name  \
# sku
# N1242D2VB-K11  DRY YOGA - T-shirt basique - deep royal blue/b...
# PI982F01N-Q11                       7 PACK - Chaussettes - black
# PI982F01N-A11                       7 PACK - Chaussettes - white
# TO152D080-Q11                         HAMPTON - Ceinture - black
# CF522P01K-C11                              NECETVO - Polo - gris
#
#                                sizes  \
# sku
# N1242D2VB-K11              [S, M, L]
# PI982F01N-Q11         [39-42, 43-46]
# PI982F01N-A11         [39-42, 43-46]
# TO152D080-Q11  [80, 85, 90, 95, 100]
# CF522P01K-C11     [S, M, L, XL, XXL]
#
#                                                          url_key  \
# sku
# N1242D2VB-K11  nike-performance-m-nk-dry-top-ss-t-shirt-basiq...
# PI982F01N-Q11          pier-one-7-pack-chaussettes-pi982f01n-q11
# PI982F01N-A11    pier-one-7-pack-chaussettes-white-pi982f01n-a11
# ...

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here

df.brand_name.value_counts()
# Out:
# Jack & Jones         21
# New Balance          20
# Levi's®              18
# Tommy Hilfiger       17
# Nike Sportswear      16
#                      ..
# Polo Ralph Lauren     1
# PULL&BEAR             1
# D-STRUCT              1
# Lee                   1
# Cars Jeans            1
# Name: brand_name, Length: 113, dtype: int64

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Jack & Jones'

# %%
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')
df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df.head(5)
# Out:
#                                                             name  \
# sku
# LE213D004-K11             SPRINGFIELD - Mocassins - navy/red/blu
# B1744E01C-C11       EMPHASIS PACK 26L - Sac à dos - gray heather
# LE214D01F-N11            FUTURA MEGA  - Mocassins - khaki/orange
# NI113D09V-A11  AIR MAX 270 EXTREME - Mocassins - white/ghost ...
# AD123K01P-K11        TREFOIL CREW - Sweatshirt - dark blue/white
#
#                                                            sizes  \
# sku
# LE213D004-K11                           [30, 31, 32, 33, 34, 35]
# B1744E01C-C11                                         [One Size]
# LE214D01F-N11               [30, 31, 32, 33, 34, 36, 37, 38, 39]
# NI113D09V-A11  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# AD123K01P-K11      [8-9a, 9-10a, 10-11a, 11-12a, 12-13a, 13-14a]
#
#                                                          url_key  \
# sku
# LE213D004-K11     levisr-baskets-basses-navyredblu-le213d004-k11
# ...

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df['price_original']=df['price.original'].astype(float)
df1=df.copy()
df1.head(5)
# Out:
#                                                             name  \
# sku
# LE213D004-K11             SPRINGFIELD - Mocassins - navy/red/blu
# B1744E01C-C11       EMPHASIS PACK 26L - Sac à dos - gray heather
# LE214D01F-N11            FUTURA MEGA  - Mocassins - khaki/orange
# NI113D09V-A11  AIR MAX 270 EXTREME - Mocassins - white/ghost ...
# AD123K01P-K11        TREFOIL CREW - Sweatshirt - dark blue/white
#
#                                                            sizes  \
# sku
# LE213D004-K11                           [30, 31, 32, 33, 34, 35]
# B1744E01C-C11                                         [One Size]
# LE214D01F-N11               [30, 31, 32, 33, 34, 36, 37, 38, 39]
# NI113D09V-A11  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# AD123K01P-K11      [8-9a, 9-10a, 10-11a, 11-12a, 12-13a, 13-14a]
#
#                                                          url_key  \
# sku
# LE213D004-K11     levisr-baskets-basses-navyredblu-le213d004-k11
# ...

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount
total_disc.sort_values(ascending=False)
# Out:
# brand_name
# Nike Sportswear       2825.80
# adidas Originals       397.05
# adidas Performance     328.50
# Levi's®                290.65
# Fila                   255.80
#                        ...
# Ellesse                  7.40
# New Era                  7.40
# Schott                   6.60
# ASICS                    4.00
# Lego Bags                2.50
# Name: discount_amount, Length: 76, dtype: float64

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Nike Sportswear'

# %%
total_disc[total_disc==0]
# Out:
# Series([], Name: discount_amount, dtype: float64)

# %%
total_value=df1.groupby(['brand_name']).sum().price_original
total_value.sort_values(ascending=False)
# Out:
# brand_name
# Nike Sportswear       5983.70
# adidas Originals       986.05
# Levi's®                663.20
# adidas Performance     655.35
# Fila                   519.55
#                        ...
# OshKosh                 26.95
# Tiffosi                 25.95
# Lego Bags               24.95
# New Era                 24.95
# Schott                  19.90
# Name: price_original, Length: 76, dtype: float64

# %%
total_value2=df1.groupby(['brand_name']).sum()
total_value2['perc_discount']=total_value2['discount_amount'].astype(float)/total_value2['price_original'].astype(float)
total_value2['perc_discount'].sort_values(ascending=False)
# Out:
# brand_name
# Napapijri            0.700000
# Billabong            0.600667
# Under Armour         0.600667
# Burton               0.600522
# Petrol Industries    0.600334
#                        ...
# Birkenstock          0.251137
# Ellesse              0.247078
# Polo Ralph Lauren    0.162325
# Lego Bags            0.100200
# ASICS                0.100125
# Name: perc_discount, Length: 76, dtype: float64
